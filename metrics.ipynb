# %%
import numpy as np
import cv2
import skimage
import os
from scipy.ndimage import binary_erosion, binary_closing, binary_dilation
from skimage.morphology import disk
import json
import pingouin 
import pandas as pd

# %%
# Generate test files
h, w = 900, 900
marker_size = 300
border_size = 20
print_size_mm = 50

mm_per_pixel = print_size_mm / h
px_per_mm = (h + border_size * 2) / print_size_mm
print("mm per px: ", mm_per_pixel)
print("px per mm: ", px_per_mm)

# Generate backdrop
backdrop = np.zeros((h, w, 3), dtype=np.uint8)
backdrop[:, :, 2] = 255
backdrops = {}
marker_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_50)
for i in range(15):

    # generate marker
    marker = cv2.aruco.generateImageMarker(marker_dict, i, marker_size)

    marker = np.expand_dims(marker, 2)
    marker[:, :, 1:] = 0   # put marker in red channel

    # create fresh backdrop
    backdrop = np.zeros((h, w, 3), dtype=np.uint8)
    backdrop[:, :, 2] = 255

    # place marker
    mh, mw = marker.shape[:2]
    backdrop[marker_size:mh + marker_size, marker_size:mw + marker_size] = marker

    # add blue highlight if you want
    backdrop[marker_size:mh + marker_size, marker_size:mw + marker_size, 0] = 255

    # store lookup
    backdrops[i] = backdrop

def add_border_write(img, name, border_size) :
    img_with_border = cv2.copyMakeBorder(
        img,
        border_size, border_size, border_size, border_size,                 # top, bottom, left, right
        cv2.BORDER_CONSTANT,
        value=(0, 0, 255)               # red in BGR
    )
    img_with_border[:border_size, :border_size] = np.array([255, 0, 0])
    img_with_border[h+border_size:, :border_size] = np.array([255, 0, 0])
    img_with_border[:border_size, w+border_size:] = np.array([255, 0, 0])
    img_with_border[-border_size:, -border_size:] = np.array([255, 0, 0])
    # TODO blue corners
    cv2.imwrite(f"{name}.png", img_with_border)
# Out:
# mm per px:  0.05555555555555555
# px per mm:  18.8

# %%
lower_red1 = np.array([0, 200, 200])
upper_red1 = np.array([20, 255, 255])

lower_red2 = np.array([160, 200, 200])
upper_red2 = np.array([180, 255 , 255])

red_range = [(lower_red1, upper_red1), (lower_red2, upper_red2)]

lower_black = np.array([0, 0, 0])
upper_black = np.array([180, 150, 200])

black_range = (lower_black, upper_black)

lower_white = np.array([0, 0, 180])
upper_white = np.array([180, 50, 255])

white_range = (lower_white, upper_white)

lower_blue = np.array([100, 80, 50])
upper_blue = np.array([130, 255, 255])

blue_range = (lower_blue, upper_blue)

def get_mask(bgr_img: np.ndarray, ranges: tuple[np.ndarray] | list[tuple[np.ndarray]]) -> np.ndarray[np.bool]:
    hsv = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2HSV)
    if(type(ranges) is tuple):
        ranges = [ranges]

    mask = None
    for range in ranges:
        lower = range[0]
        upper = range[1]
        if mask is None:
            mask = cv2.inRange(hsv, lower, upper)
        else:
            mask = mask | cv2.inRange(hsv, lower, upper)

    return mask

# %%
# Generate circle

def generate_circle(img, idx, size, thickness = 2):
    row = idx % 3
    col = idx // 3
    cv2.circle(img, (int(w * 1/3 * row + size * 1.5), int(h * 1/3 * col + size * 1.5)), size, (255, 255, 255), thickness, lineType=cv2.LINE_AA)
    return img

def generate_ellipse(img, angle, center, thickness = 2):

    axes = (250//2, 100//2)              # x-radius, y-radius
    angle = angle                     # rotation
    startAngle = 0
    endAngle = 360

    cv2.ellipse(
        img,
        center,
        axes,
        angle,
        startAngle,
        endAngle,
        (255,255,255),
        thickness=thickness,
        lineType=cv2.LINE_AA
    )

    return img

circle = backdrops[0].copy()
for i in range(0, 4):
    circle = generate_circle(circle, i, 100)
for i in range(5, 9):
    row = i % 3
    col = i // 3
    angle_rad = 2 * np.pi * (i - 3) / 8
    center = (
        int(w * (row + 0.5) / 3),
        int(h * (col + 0.5) / 3)
    )
    circle = generate_ellipse(circle, np.rad2deg(angle_rad), center)
add_border_write(circle, 0, border_size)

circle_filled = backdrops[1].copy()
for i in range(0, 4):
    circle_filled = generate_circle(circle_filled, i, 100, -1)
for i in range(5, 9):
    row = i % 3
    col = i // 3
    angle_rad = 2 * np.pi * (i - 3) / 8
    center = (
        int(w * (row + 0.5) / 3),
        int(h * (col + 0.5) / 3)
    )
    circle_filled = generate_ellipse(circle_filled, np.rad2deg(angle_rad), center, -1)
add_border_write(circle_filled, 1, border_size)

# %%
# Generate sine

def generate_wave_rotated(img, center, theta, box_size, padding, amp_factor, cycles=1):
    amplitude = box_size / 2 - padding
    amplitude *= amp_factor
    length = box_size - padding * 2

    frequency = 2 * np.pi / length * cycles

    dx = np.cos(theta)
    dy = np.sin(theta)

    # perpendicular direction
    nx = -dy
    ny = dx

    points = []

    for t in range(length):
        base_x = center[0] + dx * (t - length // 2)
        base_y = center[1] + dy * (t - length // 2)

        offset = amplitude * np.sin(frequency * t)

        x = base_x + nx * offset
        y = base_y + ny * offset

        points.append((int(x), int(y)))

    points = np.array(points, dtype=np.int32)

    cv2.polylines(img, [points], False, (255,255,255), 2, cv2.LINE_AA)
    return img


waves = backdrops[2].copy()

for i in range(0, 4):
    row = i % 3
    col = i // 3

    center = (
        int(w * (row + 0.5) / 3),
        int(h * (col + 0.5) / 3)
    )

    waves = generate_wave_rotated(
        waves,
        center,
        theta = np.pi / 2 if i % 2 == 0 else 0, #2 * np.pi * (i - 1) / 8,
        amp_factor = 1 if i > 2 else -1,
        box_size=300,
        padding=50
    )

for i in range(5, 9):
    row = i % 3
    col = i // 3

    center = (
        int(w * (row + 0.5) / 3),
        int(h * (col + 0.5) / 3)
    )

    waves = generate_wave_rotated(
        waves,
        center,
        theta = 2 * np.pi * (i - 3) / 8,
        amp_factor = 0,
        box_size=300,
        padding=50
    )
add_border_write(waves, 2, border_size)

# %%
# Extract baseline skeleton

def extract_baseline_skeleton(img_id, draw=False):
    img = cv2.imread(f"{img_id}.png")
    img = img[border_size:-border_size, border_size:-border_size]
    mask_white = get_mask(img, white_range)
    # remove border
    mask_white[marker_size:marker_size*2, marker_size:marker_size*2] = 0
    skeleton = skimage.morphology.skeletonize(mask_white > 0)
    if draw:
        mask_uint8 = mask_white.astype('uint8')
        skeleton_uint8 = (skeleton.astype('uint8')) * 255
        cv2.imshow("mask", mask_uint8)
        cv2.waitKey(0)
        cv2.imshow("skeleton", skeleton_uint8)
        cv2.waitKey(0)
    return skeleton

# %%
def _interactive_corners(image, corners, expected_marker_corners, h, w, id, filename, skip_refining = False):
    # TODO rotate
    CORNER_LABELS = ["TL", "TR", "BR", "BL"]
    KEY_TAB   = 9
    KEY_ENTER = 13
    KEY_UP    = 0x280000
    KEY_DOWN  = 0x260000
    KEY_LEFT  = 0x270000
    KEY_RIGHT = 0x250000
    KEY_PLUS  = 0x3d
    KEY_MINUS = 0x2d
    KEY_SPACE = 32
    KEY_R = 114

    ordered_keys = [KEY_UP, KEY_RIGHT, KEY_DOWN, KEY_LEFT]
    rotation = 0

    def get_rotated_key(raw_key_input, rotations):
        try:
            idx = ordered_keys.index(raw_key_input)
            key = ordered_keys[(idx + rotations) % 4]
        except(ValueError):
            key = raw_key_input
        return key

    show_overlay = True

    json_name = f'{filename[:-4]}_{id}.json'
    in_target = ["target/" + path for path in os.listdir("target")]
    if json_name in in_target:
        with open(json_name, 'r') as file:
            data = json.load(file)
            corners = np.array(data)
    corners = corners.astype(np.float32)
    if skip_refining:
        return corners

    dst_pts = expected_marker_corners.astype(np.float32)
    selected = 0
    step = 1

    window = "Warp preview  |  Arrows: nudge  Tab: next  +/-: step  Enter: accept"
    cv2.namedWindow(window, cv2.WINDOW_NORMAL)

    def render(id, show_overlay):
        H = cv2.getPerspectiveTransform(corners, dst_pts)
        warped = cv2.warpPerspective(image, H, (h, w))
        x, y = corners[selected]
        cv2.putText(warped,
                    f"Corner {selected} ({CORNER_LABELS[selected]})  src=({int(x)},{int(y)})  step={step}",
                    (10, 24), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 1, cv2.LINE_AA)
        cv2.putText(warped, "Tab: next corner   Enter: accept",
                    (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (200, 200, 200), 1, cv2.LINE_AA)
        if id != 1:
            baseline_skeleton = extract_baseline_skeleton(id)
            warped[baseline_skeleton] = np.array((0, 255, 0))
        else:
            img = cv2.imread(f"{id}.png")
            img = img[border_size:-border_size, border_size:-border_size]
            mask_white = get_mask(img, white_range)
            # remove border
            mask_white[marker_size:marker_size*2, marker_size:marker_size*2] = 0
            mask_white = mask_white.astype(np.bool)
            if show_overlay:
                warped[mask_white] = np.array((0, 255, 0))
                cv2.imwrite("warped.png", warped)

        if show_overlay:
            cv2.rectangle(warped, (h//3, w//3), ((h//3) * 2, (w//3) * 2), (0, 255, 0), 1)
        return warped

    while True:
        cv2.imshow(window, render(id, show_overlay))
        raw_key = cv2.waitKeyEx(0)  # waitKeyEx needed for arrow keys
        key = get_rotated_key(raw_key, rotation)

        # Temporary debug — remove once keys are confirmed
        # print(f"key={key}  hex={hex(key & 0xFFFFFFFF)}")

        if key == KEY_ENTER:
            break
        elif key == KEY_TAB:
            selected = (selected + 1) % 4
        elif key == KEY_PLUS:
            step = min(step * 2, 64)
        elif key == KEY_MINUS:
            step = max(step / 2, 0.25)
        elif key == KEY_UP:
            corners[selected][1] -= step
        elif key == KEY_DOWN:
            corners[selected][1] += step
        elif key == KEY_LEFT:
            corners[selected][0] -= step
        elif key == KEY_RIGHT:
            corners[selected][0] += step
        elif key == KEY_SPACE:
            show_overlay = not show_overlay
        elif key == KEY_R:
            rotation += 1

    with open(json_name, 'w') as file:
        json.dump(corners.tolist(), file, indent=4)
    cv2.destroyWindow(window)
    return corners


def rectify_scan(filename, draw=False, skip_refining = False):
    # TODO 
    baseline_scan = cv2.imread(filename)
    tag_mask = ~get_mask(baseline_scan, blue_range)

    params = cv2.aruco.DetectorParameters()
    params.cornerRefinementMethod = cv2.aruco.CORNER_REFINE_SUBPIX
    params.cornerRefinementWinSize = 5
    params.cornerRefinementMaxIterations = 2000
    params.cornerRefinementMinAccuracy = 0.0001

    detector = cv2.aruco.ArucoDetector(marker_dict, params)
    corners, ids, rejected = detector.detectMarkers(tag_mask)
    id_mapped_corners = {int(id[0]): corner[0] for id, corner in zip(ids, corners)}
    expected_marker_corners = np.array([
        [marker_size, marker_size],
        [marker_size * 2, marker_size],
        [marker_size * 2, marker_size * 2],
        [marker_size, marker_size * 2]
    ], dtype=np.float32)

    if draw:
        cv2.imshow("marker", cv2.aruco.drawDetectedMarkers(baseline_scan, corners, ids))
        cv2.waitKeyEx(0)

    id_mapped_images = {}
    for marker_id, marker_corners in id_mapped_corners.items():
        refined = _interactive_corners(
            baseline_scan,
            marker_corners.copy(),
            expected_marker_corners,
            h, w,  # your existing globals
            marker_id, filename,
            skip_refining=skip_refining
        )
        H = cv2.getPerspectiveTransform(refined, expected_marker_corners)
        img = cv2.warpPerspective(baseline_scan, H, (h, w))
        id_mapped_images[marker_id] = img
        if draw:
            cv2.imshow("test", img)
            cv2.waitKeyEx(0)

    return id_mapped_images

# %%
# Read drawing
def extract_drawn_skeleton(img, prune_iterations, draw=False):
    mask_drawn = get_mask(img, black_range)
    mask_drawn[marker_size-10:marker_size*2+10, marker_size-10:marker_size*2+10] = 0 # Take out aruco tag

    mask_drawn = mask_drawn.astype(np.bool)

    # slightly dilate red mask to remove speckles / noise
    mask_red = get_mask(img, red_range)
    mask_red = mask_red.astype(np.bool)
    mask_red = binary_dilation(mask_red, structure=disk(2))
    mask_red = binary_erosion(mask_red, structure=disk(2))
    
    # TODO bug - these masks are uint8, not boolean
    # Undefined behavior for showing & boolean operations
    # Cast to bool first
    cv2.imshow("Before", mask_drawn.astype('uint8') * 255)
    cv2.waitKey(0)
    cv2.imshow("Red Mask", mask_red.astype('uint8') * 255)
    cv2.waitKey(0)
    # mask_drawn[mask_red] = 0
    cv2.imshow("After", mask_drawn.astype('uint8') * 255)
    cv2.waitKey(0)

    mask_drawn = binary_closing(mask_drawn, structure=disk(2)) # Fill holes
    # mask_drawn = binary_erosion(mask_drawn, structure=disk(3))
    mask_drawn = binary_erosion(mask_drawn, structure=disk(2))
    mask_drawn = binary_erosion(mask_drawn, structure=disk(1))

    skeleton = skimage.morphology.skeletonize(mask_drawn > 0)
    skeleton = prune_skeleton(skeleton, prune_iterations)
    if draw:
        mask_uint8 = mask_drawn.astype('uint8') * 255
        skeleton_uint8 = (skeleton.astype('uint8')) * 255
        cv2.imshow("mask", mask_uint8)
        cv2.waitKey(0)
        cv2.imshow("skeleton", skeleton_uint8)
        cv2.waitKey(0)
    return skeleton

def get_neighbors(img):
    kernel = np.array([[1,1,1],
                       [1,10,1],
                       [1,1,1]], dtype=np.uint8)
    return cv2.filter2D(img.astype(np.uint8), -1, kernel)

def prune_skeleton(skel, iterations=10):
    for _ in range(iterations):
        skeleton_uint8 = skel.copy().astype(np.uint8)
        neighbors = get_neighbors(skeleton_uint8)
        
        # endpoint = value 11 (10 self + 1 neighbor)
        endpoints = (neighbors == 11)
        islands = (neighbors == 10)
        
        skel[endpoints] = 0
        skel[islands] = 0
    return skel

# %%
# Computer per-pixel distance of every pixel against the reference

def process_traced_path(original_skeleton, drawn_skeleton, draw=False, verbose=True):
    distance_drawn_to_gt = cv2.distanceTransform((~original_skeleton).astype(np.uint8), cv2.DIST_L2, 3)
    distance_drawn_to_gt[~drawn_skeleton] = 0
    if draw:
        cv2.imshow("distance", distance_drawn_to_gt.astype(np.float32) / np.max(distance_drawn_to_gt.astype(np.float32)))
        cv2.waitKey(0)
    distance_gt_to_drawn = cv2.distanceTransform((~drawn_skeleton).astype(np.uint8), cv2.DIST_L2, 3)
    distance_gt_to_drawn[~original_skeleton] = 0

    # For each pixel in distance_drawn_to_gt != 0
    # Add to histogram

    error_d_gt = np.sum(distance_drawn_to_gt)
    count_d_gt = np.count_nonzero(distance_drawn_to_gt)
    error_gt_d = np.sum(distance_gt_to_drawn)
    count_gt_d = np.count_nonzero(distance_gt_to_drawn)
    asymmetric = error_d_gt/count_d_gt
    symmetric = (error_d_gt/count_d_gt + error_gt_d/count_gt_d) / 2

    if verbose:
        print(f"Asymmetric error (Deviation from path): {asymmetric:3f}")
        print(f"Symmetric error (Completeness): {symmetric:3f}")
    distance_drawn_to_gt = distance_drawn_to_gt.astype(np.float32)
    distance_drawn_to_gt /= np.max(distance_drawn_to_gt)
    distance_red = (distance_drawn_to_gt * 255).astype(np.uint8)
    distance_green = ((1 - distance_drawn_to_gt) * 255).astype(np.uint8)

    # Create a blank BGR image
    # circle_skeleton = skimage.morphology.skeletonize(mask_black > 0)
    # skeleton_uint8 = (circle_skeleton.astype('uint8')) * 255
    overlay = np.zeros((original_skeleton.shape[0], original_skeleton.shape[1], 3), dtype=np.uint8)

    # Blue channel = skeleton
    overlay[:, :, 0] = original_skeleton

    # Red channel = distance intensity
    # overlay[:, :, 1] = distance_green
    overlay[:, :, 2] = distance_red

    cv2.imwrite("overlay.png", cv2.dilate(overlay, np.ones((3, 3))))

    return asymmetric, distance_drawn_to_gt

# %%
def slice_generator(gt_img, pred_img):
    slice_size = w // 3
    counter = 0
    for i in range(0, h, slice_size):
        for j in range(0, w, slice_size):
            if i == j and i == h//3:
                continue
            if len(gt_img.shape) == 2:
                gt_slice = gt_img[i:i+slice_size, j:j+slice_size]
                pred_slice = pred_img[i:i+slice_size, j:j+slice_size]
            else:
                gt_slice = gt_img[i:i+slice_size, j:j+slice_size, :]
                pred_slice = pred_img[i:i+slice_size, j:j+slice_size, :]
            yield gt_slice, pred_slice, counter
            counter += 1

# %%
data = [] #Subject: id (shape x angle), Within: mode (hand, rt, planned), dv: error

files = os.listdir("target")
for id in (0,):
    prune_iterations = 20 if id == 0 else 0
    name = "closed_trace" if id == 0 else "open_trace"
    print("\n" + name)
    for filename in files:
        if filename[-4:] != ".png": continue
        path = f"target/{filename}"
        id_mapped_drawings = rectify_scan(path, skip_refining=True)
        drawn_skeleton = extract_drawn_skeleton(id_mapped_drawings[id], prune_iterations=prune_iterations, draw=True)
        marked_up_image = id_mapped_drawings[id]
        baseline_skeleton = extract_baseline_skeleton(id, draw=False)
        marked_up_image[baseline_skeleton] = np.array((0, 255, 0))
        marked_up_image[drawn_skeleton] = np.array((255, 0, 0))
        cv2.imwrite(f"{filename[:-4]}_out.png", marked_up_image)
        print(path)
        for baseline_skeleton_slice, drawn_skeleton_slice, count in slice_generator(baseline_skeleton, drawn_skeleton):
            error, distance_drawn_to_gt = process_traced_path(baseline_skeleton_slice, drawn_skeleton_slice, verbose=False, draw=False)
            error *= mm_per_pixel
            data.append((count + (8 if id == 2 else 0), filename, error))

df = pd.DataFrame(data, columns=['subject', 'mode', 'dv'])
print(df)
# Out:
# closed_trace
# target/kangcontroller-1.png
# target/kangplanned-1.png
# target/kangrealtime-1.png
#     subject                  mode        dv
# 0         0  kangcontroller-1.png  0.368368
# 1         1  kangcontroller-1.png  0.563432
# 2         2  kangcontroller-1.png  0.488656
# 3         3  kangcontroller-1.png  0.581225
# 4         4  kangcontroller-1.png  0.861502
# 5         5  kangcontroller-1.png  0.358541
# 6         6  kangcontroller-1.png  0.828953
# 7         7  kangcontroller-1.png  0.635104
# 8         0     kangplanned-1.png  0.168786
# 9         1     kangplanned-1.png  0.259936
# 10        2     kangplanned-1.png  0.307983
# 11        3     kangplanned-1.png  0.200706
# 12        4     kangplanned-1.png  0.300533
# 13        5     kangplanned-1.png  0.166694
# 14        6     kangplanned-1.png  0.170418
# 15        7     kangplanned-1.png  0.276066
# 16        0    kangrealtime-1.png  0.158289
# 17        1    kangrealtime-1.png  0.189056
# ...

# %%
aov = pingouin.rm_anova(
    data=df,
    dv='dv',
    within='mode',
    subject='subject',
    detailed=True
)

print(aov)
# Out:
#   Source        SS  DF        MS          F     p_unc  p_GG_corr      ng2  \
# 0   mode  0.747981   2  0.373991  30.038227  0.000009   0.000348  0.72152
# 1  Error  0.174307  14  0.012450        NaN       NaN        NaN      NaN
#
#         eps sphericity   W_spher   p_spher
# 0  0.603275      False  0.342382  0.040136
# 1       NaN        NaN       NaN       NaN

# %%
posthoc = pingouin.pairwise_tests(
    data=df,
    dv='dv',
    within='mode',
    subject='subject',
    padjust='holm'
)

print(posthoc)
# Out:
#   Contrast                     A                   B  Paired  Parametric  \
# 0     mode  kangcontroller-1.png   kangplanned-1.png    True        True
# 1     mode  kangcontroller-1.png  kangrealtime-1.png    True        True
# 2     mode     kangplanned-1.png  kangrealtime-1.png    True        True
#
#           T  dof alternative     p_unc    p_corr p_adjust    BF10    hedges
# 0  5.665601  7.0   two-sided  0.000762  0.002286     holm  51.437  2.400474
# 1  5.663405  7.0   two-sided  0.000764  0.002286     holm  51.341  2.705623
# 2  1.482907  7.0   two-sided  0.181663  0.181663     holm   0.756  0.645480

# %%
df.groupby('mode')['dv'].mean()
# Out:
# mode
# fhand-1.png           0.330044
# fplannedreal-1.png    0.306801
# frealtime-1.png       0.323001
# Name: dv, dtype: float32

# %%
import matplotlib.pyplot as plt
import numpy as np

# Original order in df might be ['hand', 'planned', 'rt'], let's reorder to: hand, rt, planned
modes = ['controller', 'rt', 'planned']

# Build data in that order
data = [
    df[df['mode'] == 'kangcontroller-1.png']['dv'].values,
    df[df['mode'] == 'kangplanned-1.png']['dv'].values,
    df[df['mode'] == 'kangrealtime-1.png']['dv'].values
]

plt.figure(figsize=(7,5))
plt.boxplot(data, labels=modes)

# Optional: overlay individual points with jitter
for i, y in enumerate(data):
    x = np.random.normal(i + 1, 0, size=len(y))  # jitter
    plt.scatter(x, y, alpha=0.7)

plt.xlabel("Drawing Mode")
plt.ylabel("Asymmetric Distance (mm)")
plt.title("Performance Across Drawing Modes")
plt.show()
# Out:
# C:\Users\0dps1\AppData\Local\Temp\ipykernel_4688\518564626.py:15: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=modes)

# %%
# Read filled drawing

def process_filled_path(original_img, drawn_img):
    # drawn_img[:int(marker_size * 1.05), :int(marker_size * 1.05), :] = 255
    # drawn_img[int(h*0.9):, :, :] = 255
    # drawn_img[:, int(w*0.9):, :] = 255
    # circle_filled = cv2.imread("3.png")
    drawn_img[:int(marker_size * 1.05), :int(marker_size * 1.05)] = np.array([0, 0, 255])
    mask_drawn = get_mask(drawn_img, black_range)
    mask_gt = get_mask(original_img, white_range)
    tp = np.count_nonzero(mask_drawn & mask_gt)
    fp = np.count_nonzero(mask_drawn & ~mask_gt)
    fn = np.count_nonzero(~mask_drawn & mask_gt)
    tn = np.count_nonzero(~mask_drawn & ~mask_gt)

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0  # sensitivity
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0

    print(f"TP: {tp}")
    print(f"FP: {fp}")
    print(f"FN: {fn}")
    print(f"TN: {tn}")
    print(f"Precision: {precision:.4f}")
    print(f"Sensitivity (Recall): {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

    tp_mask = (mask_drawn & mask_gt).astype(np.uint8)
    fp_mask = (mask_drawn & ~mask_gt).astype(np.uint8)

    precision_img = np.zeros_like(circle_filled)

    # OpenCV uses BGR
    precision_img[:, :, 0] = tp_mask   # Blue channel → TP
    precision_img[:, :, 2] = fp_mask   # Red channel → FP

    cv2.imshow("precision", precision_img)
    cv2.waitKey(0)

    # True positives
    tp_mask = (mask_drawn & mask_gt).astype(np.uint8)
    # False negatives (missed GT)
    fn_mask = (~mask_drawn & mask_gt).astype(np.uint8)

    recall_img = np.zeros_like(circle_filled)

    # OpenCV BGR: blue = TP, red = FN
    recall_img[:, :, 0] = tp_mask   # Blue channel → TP
    recall_img[:, :, 2] = fn_mask   # Red channel → FN

    cv2.imshow("recall", recall_img)
    cv2.waitKey(0)

# %%
id = 1
name = "filled"
print("\n" + name)
for filename in files:
    if filename[-4:] != ".png": continue
    print(filename)
    path = f"target/{filename}"
    id_mapped_drawings = rectify_scan(path, skip_refining=True)
    original_img = cv2.imread(f"{id}.png")
    original_img = original_img[border_size:-border_size, border_size:-border_size]
    # remove border
    original_img[:marker_size, :marker_size] = np.array([0, 0, 255])
    rectified_drawn_image = id_mapped_drawings[id]
    process_filled_path(original_img, rectified_drawn_image)
# Out:
# filled
# fhand-1.png
# TP: 184894
# FP: 32991
# FN: 9313
# TN: 582802
# Precision: 0.8486
# Sensitivity (Recall): 0.9520
# F1 Score: 0.8973
# fplannedreal-1.png
# TP: 176919
# FP: 35211
# FN: 17288
# TN: 580582
# Precision: 0.8340
# Sensitivity (Recall): 0.9110
# F1 Score: 0.8708
# frealtime-1.png
# TP: 192318
# FP: 79849
# FN: 1889
# TN: 535944
# Precision: 0.7066
# Sensitivity (Recall): 0.9903
# F1 Score: 0.8247

# %%
error_nonzero = distance_drawn_to_gt[distance_drawn_to_gt != 0].flatten()
print("Mean error: ", np.mean(error_nonzero))
print("95th percentile error: ", np.percentile(error_nonzero, 95))
print("Stddev: ", np.std(error_nonzero))
error_lt_threshold = error_nonzero[error_nonzero < 1]
print("Below threshold: ", error_lt_threshold.shape[0] / error_nonzero.shape[0])
# Out:
# Mean error:  0.63958675
# 95th percentile error:  0.96638185
# Stddev:  0.21609682
# Below threshold:  0.9746835443037974
