# %%
import numpy as np
import cv2
import skimage

# %%
# Generate test files
h, w = 800, 800
marker_size = 200

# Generate backdrop
backdrop = np.zeros((h, w, 3), dtype=np.uint8)
backdrop[:, :, 2] = 255
backdrops = {}
marker_dict = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_50)
for i in range(15):

    # generate marker
    marker = cv2.aruco.generateImageMarker(marker_dict, i, marker_size)

    marker = np.expand_dims(marker, 2)
    marker[:, :, 1:] = 0   # put marker in red channel

    # create fresh backdrop
    backdrop = np.zeros((h, w, 3), dtype=np.uint8)
    backdrop[:, :, 2] = 255

    # place marker
    mh, mw = marker.shape[:2]
    backdrop[:mh, :mw] = marker

    # add blue highlight if you want
    backdrop[:mh, :mw, 0] = 255

    # store lookup
    backdrops[i] = backdrop

# %%
lower_red1 = np.array([0, 30, 50])
upper_red1 = np.array([20, 255, 255])

lower_red2 = np.array([160, 30, 50])
upper_red2 = np.array([180, 255 , 255])

red_range = [(lower_red1, upper_red1), (lower_red2, upper_red2)]

lower_black = np.array([0, 0, 0])
upper_black = np.array([180, 255, 180])

black_range = (lower_black, upper_black)

lower_white = np.array([0, 0, 180])
upper_white = np.array([180, 50, 255])

white_range = (lower_white, upper_white)

lower_blue = np.array([100, 80, 50])
upper_blue = np.array([130, 255, 255])

blue_range = (lower_blue, upper_blue)

def get_mask(bgr_img: np.ndarray, ranges: tuple[np.ndarray] | list[tuple[np.ndarray]]) -> np.ndarray[np.bool]:
    hsv = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2HSV)
    if(type(ranges) is tuple):
        ranges = [ranges]

    mask = None
    for range in ranges:
        lower = range[0]
        upper = range[1]
        if mask is None:
            mask = cv2.inRange(hsv, lower, upper)
        else:
            mask = mask | cv2.inRange(hsv, lower, upper)

    return mask

# %%
def rectify_scan(filename, draw=False, save=False):
    baseline_scan = cv2.imread(filename)
    tag_mask = ~get_mask(baseline_scan, blue_range)

    params = cv2.aruco.DetectorParameters()
    params.cornerRefinementMethod = cv2.aruco.CORNER_REFINE_SUBPIX
    params.cornerRefinementWinSize = 5
    params.cornerRefinementMaxIterations = 50
    params.cornerRefinementMinAccuracy = 0.01

    detector = cv2.aruco.ArucoDetector(marker_dict, params)
    corners, ids, rejected = detector.detectMarkers(tag_mask)
    selected_corners = np.array(corners[0][0])
    expected_marker_corners = np.array([
        [0,0],
        [marker_size, 0],
        [marker_size, marker_size],
        [0, marker_size]
    ])
    if draw:
        cv2.imshow("marker", cv2.aruco.drawDetectedMarkers(baseline_scan, corners, ids))
        cv2.waitKey(0)
    H = cv2.getPerspectiveTransform(selected_corners.astype(np.float32), expected_marker_corners.astype(np.float32))
    baseline_scan = cv2.warpPerspective(baseline_scan, H, (h, w))
    if draw:
        cv2.imshow("rectified", baseline_scan)
        cv2.waitKey(0)
    if save:
        cv2.imwrite("saved.png", baseline_scan)
    return baseline_scan

# %%
# Generate circle

def generate_circle(id, size, thickness = 3):
    circle = backdrops[id].copy()
    cv2.circle(circle, (int(w * 0.5), int(h * 0.5)), size, (255, 255, 255), thickness, lineType=cv2.LINE_AA)
    cv2.imwrite(f"{id}.png", circle)
generate_circle(0, 75)
generate_circle(1, 125)
generate_circle(2, 200)
generate_circle(3, 75, -1)
generate_circle(4, 125, -1)
generate_circle(5, 200, -1)

# %%
# Generate sine

def generate_wave(id, map, cycles = 1):
    img = backdrops[id].copy()

    amplitude = 150
    snip_size = 100
    snipped_width = w - snip_size * 2
    frequency = 2 * np.pi / snipped_width * cycles   # 4 cycles across width
    y_center = h // 2

    points = []

    for x in range(snipped_width):
        y = int(y_center + amplitude * np.sin(frequency * x))
        points.append(map((x + snip_size, y)))

    points = np.array(points, dtype=np.int32)

    cv2.polylines(img, [points], False, (255,255,255), 10, cv2.LINE_AA)

    cv2.imwrite(f"{id}.png", img)

generate_wave(10, lambda point: (point[0], point[1]), 0)
generate_wave(11, lambda point: (point[1], point[0]), 0)
generate_wave(6, lambda point: (point[0], point[1]))
generate_wave(7, lambda point: (point[1], point[0]))
generate_wave(8, lambda point: (point[0], point[1]), -1)
generate_wave(9, lambda point: (point[1], point[0]), -1)

# %%
def generate_ellipse(id, angle):

    ellipse = backdrops[id].copy()

    center = (w//2, h//2)
    axes = (250, 100)              # x-radius, y-radius
    angle = angle                     # rotation
    startAngle = 0
    endAngle = 360

    cv2.ellipse(
        ellipse,
        center,
        axes,
        angle,
        startAngle,
        endAngle,
        (255,255,255),
        thickness=-1,
        lineType=cv2.LINE_AA
    )

    cv2.imwrite(f"{id}.png", ellipse)
generate_ellipse(12, 0)
generate_ellipse(13, 45)
generate_ellipse(14, 90)

# %%
# Extract baseline skeleton

mask_black = get_mask(cv2.imread("8.png"), white_range)
mask_black[:marker_size, :marker_size] = 0
mask_uint8 = mask_black.astype('uint8')
cv2.imshow("mask", mask_uint8)
cv2.waitKey(0)
circle_skeleton = skimage.morphology.skeletonize(mask_black > 0)
skeleton_uint8 = (circle_skeleton.astype('uint8')) * 255
cv2.imshow("skeleton", skeleton_uint8)
cv2.waitKey(0)
# Out:
# -1

# %%
# Read drawing
circle_drawn = rectify_scan("fichera_wave.png", save=True)
mask_drawn = get_mask(circle_drawn, black_range)
mask_drawn[:marker_size+10, :marker_size+10] = 0
mask_drawn[h-40:h, :] = 0
mask_drawn[:, w-40:w] = 0
mask_uint8 = mask_drawn.astype('uint8')
cv2.imshow("mask", mask_uint8)
cv2.waitKey(0)
circle_drawn_skeleton = skimage.morphology.skeletonize(mask_drawn > 0)
skeleton_uint8 = (circle_drawn_skeleton.astype('uint8')) * 255
cv2.imshow("skeleton", skeleton_uint8)
cv2.waitKey(0)
# Out:
# -1

# %%
# Computer per-pixel distance of every pixel against the reference
distance_drawn_to_gt = cv2.distanceTransform((~circle_skeleton).astype(np.uint8), cv2.DIST_L2, 3)
distance_drawn_to_gt[~circle_drawn_skeleton] = 0
distance_gt_to_drawn = cv2.distanceTransform((~circle_drawn_skeleton).astype(np.uint8), cv2.DIST_L2, 3)
distance_gt_to_drawn[~circle_skeleton] = 0

error_d_gt = np.sum(distance_drawn_to_gt)
count_d_gt = np.count_nonzero(distance_drawn_to_gt)
error_gt_d = np.sum(distance_gt_to_drawn)
count_gt_d = np.count_nonzero(distance_gt_to_drawn)
asymmetric = error_d_gt/count_d_gt
symmetric = (error_d_gt/count_d_gt + error_gt_d/count_gt_d) / 2

print(f"Asymmetric error (Deviation from path): {asymmetric:3f}")
print(f"Symmetric error (Completeness): {symmetric:3f}")
distance_drawn_to_gt = distance_drawn_to_gt.astype(np.float32)
distance_drawn_to_gt /= np.max(distance_drawn_to_gt)
cv2.imshow("distance", distance_drawn_to_gt)
cv2.waitKey(0)
distance_red = (distance_drawn_to_gt * 255).astype(np.uint8)

# Create a blank BGR image
circle_skeleton = skimage.morphology.skeletonize(mask_black > 0)
skeleton_uint8 = (circle_skeleton.astype('uint8')) * 255
overlay = np.zeros((circle_skeleton.shape[0], circle_skeleton.shape[1], 3), dtype=np.uint8)

# Blue channel = skeleton
overlay[:, :, 0] = skeleton_uint8

# Red channel = distance intensity
overlay[:, :, 0] = np.maximum(overlay[:, :, 0], drawn_intensity)
overlay[:, :, 1] = np.maximum(overlay[:, :, 1], drawn_intensity)
overlay[:, :, 2] = np.maximum(overlay[:, :, 2], drawn_intensity)

cv2.imwrite("overlay.png", overlay)
# Out:
# Asymmetric error (Deviation from path): 8.202380
# Symmetric error (Completeness): 7.824461
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 31
#      28 overlay[:, :, 0] = skeleton_uint8
#      30 # Red channel = distance intensity
# ---> 31 overlay[:, :, :] = distance_red
#      33 cv2.imwrite("overlay.png", overlay)
#
# ValueError: could not broadcast input array from shape (800,800) into shape (800,800,3)

# %%
# Read filled drawing
circle_drawn = rectify_scan("kang_laze.png", False)
circle_drawn[:int(marker_size * 1.05), :int(marker_size * 1.05), :] = 255
circle_drawn[int(h*0.9):, :, :] = 255
circle_drawn[:, int(w*0.9):, :] = 255
circle_filled = cv2.imread("3.png")
circle_filled[:int(marker_size * 1.05), :int(marker_size * 1.05), :] = 0
mask_drawn = get_mask(circle_drawn, black_range)
mask_gt = get_mask(circle_filled, white_range)
tp = np.count_nonzero(mask_drawn & mask_gt)
fp = np.count_nonzero(mask_drawn & ~mask_gt)
fn = np.count_nonzero(~mask_drawn & mask_gt)
tn = np.count_nonzero(~mask_drawn & ~mask_gt)

precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0  # sensitivity
f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0

print(f"TP: {tp}")
print(f"FP: {fp}")
print(f"FN: {fn}")
print(f"TN: {tn}")
print(f"Precision: {precision:.4f}")
print(f"Sensitivity (Recall): {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

tp_mask = (mask_drawn & mask_gt).astype(np.uint8)
fp_mask = (mask_drawn & ~mask_gt).astype(np.uint8)

precision_img = np.zeros_like(circle_filled)

# OpenCV uses BGR
precision_img[:, :, 0] = tp_mask   # Blue channel → TP
precision_img[:, :, 2] = fp_mask   # Red channel → FP

cv2.imwrite("precision.png", precision_img)

# True positives
tp_mask = (mask_drawn & mask_gt).astype(np.uint8)
# False negatives (missed GT)
fn_mask = (~mask_drawn & mask_gt).astype(np.uint8)

recall_img = np.zeros_like(circle_filled)

# OpenCV BGR: blue = TP, red = FN
recall_img[:, :, 0] = tp_mask   # Blue channel → TP
recall_img[:, :, 2] = fn_mask   # Red channel → FN

cv2.imwrite("recall.png", recall_img)
# Out:
# TP: 15459
# FP: 2524
# FN: 2374
# TN: 619643
# Precision: 0.8596
# Sensitivity (Recall): 0.8669
# F1 Score: 0.8632
# True

# %%
error_nonzero = distance_drawn_to_gt[distance_drawn_to_gt != 0].flatten()
print("Mean error: ", np.mean(error_nonzero))
print("95th percentile error: ", np.percentile(error_nonzero, 95))
print("Stddev: ", np.std(error_nonzero))
error_lt_threshold = error_nonzero[error_nonzero < 1]
print("Below threshold: ", error_lt_threshold.shape[0] / error_nonzero.shape[0])
# Out:
# Mean error:  0.35874957
# 95th percentile error:  0.77856255
# Stddev:  0.21484247
# Below threshold:  0.9986357435197817
